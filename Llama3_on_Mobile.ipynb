# %% [markdown]
# #### Step 1: Install MLC LLM

# %%
# !pip install --pre --force-reinstall mlc-ai-nightly-cu122 mlc-llm-nightly-cu122 -f https://mlc.ai/wheels
# Out:
# Looking in links: https://mlc.ai/wheels
# Collecting mlc-ai-nightly-cu122
#   Downloading https://github.com/mlc-ai/package/releases/download/v0.9.dev0/mlc_ai_nightly_cu122-0.15.dev347-cp310-cp310-manylinux_2_28_x86_64.whl (1056.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 GB 801.3 kB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /wheels
# Collecting mlc-llm-nightly-cu122
#   Downloading https://github.com/mlc-ai/package/releases/download/v0.9.dev0/mlc_llm_nightly_cu122-0.1.dev1226-cp310-cp310-manylinux_2_28_x86_64.whl (159.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.1/159.1 MB 7.7 MB/s eta 0:00:00
# Collecting attrs (from mlc-ai-nightly-cu122)
#   Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 956.3 kB/s eta 0:00:00
# Collecting cloudpickle (from mlc-ai-nightly-cu122)
#   Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Collecting decorator (from mlc-ai-nightly-cu122)
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting ml-dtypes (from mlc-ai-nightly-cu122)
#   Downloading ml_dtypes-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 12.1 MB/s eta 0:00:00
# Collecting numpy (from mlc-ai-nightly-cu122)
#   Downloading numpy-2.0.0rc1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 45.8 MB/s eta 0:00:00
# Collecting psutil (from mlc-ai-nightly-cu122)
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 30.0 MB/s eta 0:00:00
# Collecting scipy (from mlc-ai-nightly-cu122)
#   Downloading scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 11.7 MB/s eta 0:00:00
# Collecting tornado (from mlc-ai-nightly-cu122)
#   Downloading tornado-6.4-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.4/435.4 kB 36.9 MB/s eta 0:00:00
# Collecting typing-extensions (from mlc-ai-nightly-cu122)
#   Downloading typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Collecting fastapi (from mlc-llm-nightly-cu122)
#   Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 11.7 MB/s eta 0:00:00
# Collecting uvicorn (from mlc-llm-nightly-cu122)
#   Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.7 MB/s eta 0:00:00
# Collecting shortuuid (from mlc-llm-nightly-cu122)
#   Downloading shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Collecting torch (from mlc-llm-nightly-cu122)
#   Downloading torch-2.3.0-cp310-cp310-manylinux1_x86_64.whl (779.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 769.9 kB/s eta 0:00:00
# Collecting safetensors (from mlc-llm-nightly-cu122)
#   Downloading safetensors-0.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.3 MB/s eta 0:00:00
# Collecting requests (from mlc-llm-nightly-cu122)
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 8.0 MB/s eta 0:00:00
# Collecting tqdm (from mlc-llm-nightly-cu122)
#   Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 10.1 MB/s eta 0:00:00
# Collecting tiktoken (from mlc-llm-nightly-cu122)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 80.5 MB/s eta 0:00:00
# Collecting prompt-toolkit (from mlc-llm-nightly-cu122)
#   Downloading prompt_toolkit-3.0.43-py3-none-any.whl (386 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.1/386.1 kB 38.8 MB/s eta 0:00:00
# Collecting openai (from mlc-llm-nightly-cu122)
#   Downloading openai-1.28.1-py3-none-any.whl (320 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.1/320.1 kB 32.6 MB/s eta 0:00:00
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->mlc-llm-nightly-cu122)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 9.4 MB/s eta 0:00:00
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 (from fastapi->mlc-llm-nightly-cu122)
#   Downloading pydantic-2.7.1-py3-none-any.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.3/409.3 kB 41.9 MB/s eta 0:00:00
# Collecting fastapi-cli>=0.0.2 (from fastapi->mlc-llm-nightly-cu122)
#   Downloading fastapi_cli-0.0.3-py3-none-any.whl (9.2 kB)
# Collecting httpx>=0.23.0 (from fastapi->mlc-llm-nightly-cu122)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.1 MB/s eta 0:00:00
# Collecting jinja2>=2.11.2 (from fastapi->mlc-llm-nightly-cu122)
#   Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 17.0 MB/s eta 0:00:00
# Collecting python-multipart>=0.0.7 (from fastapi->mlc-llm-nightly-cu122)
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi->mlc-llm-nightly-cu122)
#   Downloading ujson-5.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 6.8 MB/s eta 0:00:00
# Collecting orjson>=3.2.1 (from fastapi->mlc-llm-nightly-cu122)
#   Downloading orjson-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 17.3 MB/s eta 0:00:00
# Collecting email_validator>=2.0.0 (from fastapi->mlc-llm-nightly-cu122)
#   Downloading email_validator-2.1.1-py3-none-any.whl (30 kB)
# Collecting anyio<5,>=3.5.0 (from openai->mlc-llm-nightly-cu122)
#   Downloading anyio-4.3.0-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 10.0 MB/s eta 0:00:00
# Collecting distro<2,>=1.7.0 (from openai->mlc-llm-nightly-cu122)
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting sniffio (from openai->mlc-llm-nightly-cu122)
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting wcwidth (from prompt-toolkit->mlc-llm-nightly-cu122)
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Collecting charset-normalizer<4,>=2 (from requests->mlc-llm-nightly-cu122)
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 kB 15.9 MB/s eta 0:00:00
# Collecting idna<4,>=2.5 (from requests->mlc-llm-nightly-cu122)
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.9 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1 (from requests->mlc-llm-nightly-cu122)
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 14.9 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17 (from requests->mlc-llm-nightly-cu122)
#   Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 20.5 MB/s eta 0:00:00
# Collecting regex>=2022.1.18 (from tiktoken->mlc-llm-nightly-cu122)
#   Downloading regex-2024.5.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (774 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.1/774.1 kB 56.1 MB/s eta 0:00:00
# Collecting filelock (from torch->mlc-llm-nightly-cu122)
#   Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Collecting sympy (from torch->mlc-llm-nightly-cu122)
#   Downloading sympy-1.12.1rc1-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 50.9 MB/s eta 0:00:00
# Collecting networkx (from torch->mlc-llm-nightly-cu122)
#   Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 75.5 MB/s eta 0:00:00
# Collecting fsspec (from torch->mlc-llm-nightly-cu122)
#   Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 18.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->mlc-llm-nightly-cu122)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 2.6 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting triton==2.3.0 (from torch->mlc-llm-nightly-cu122)
#   Downloading triton-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 6.3 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->mlc-llm-nightly-cu122)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Collecting click>=7.0 (from uvicorn->mlc-llm-nightly-cu122)
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 13.1 MB/s eta 0:00:00
# Collecting h11>=0.8 (from uvicorn->mlc-llm-nightly-cu122)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.9 MB/s eta 0:00:00
# Collecting exceptiongroup>=1.0.2 (from anyio<5,>=3.5.0->openai->mlc-llm-nightly-cu122)
#   Downloading exceptiongroup-1.2.1-py3-none-any.whl (16 kB)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi->mlc-llm-nightly-cu122)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 35.9 MB/s eta 0:00:00
# Collecting typer>=0.12.3 (from fastapi-cli>=0.0.2->fastapi->mlc-llm-nightly-cu122)
#   Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 5.9 MB/s eta 0:00:00
# Collecting httpcore==1.* (from httpx>=0.23.0->fastapi->mlc-llm-nightly-cu122)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 10.8 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.0 (from jinja2>=2.11.2->fastapi->mlc-llm-nightly-cu122)
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting annotated-types>=0.4.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->mlc-llm-nightly-cu122)
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.18.2 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->mlc-llm-nightly-cu122)
#   Downloading pydantic_core-2.18.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 61.6 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn->mlc-llm-nightly-cu122)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 34.0 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn->mlc-llm-nightly-cu122)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting pyyaml>=5.1 (from uvicorn->mlc-llm-nightly-cu122)
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 45.3 MB/s eta 0:00:00
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn->mlc-llm-nightly-cu122)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 55.5 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn->mlc-llm-nightly-cu122)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.0 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn->mlc-llm-nightly-cu122)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 16.6 MB/s eta 0:00:00
# Collecting mpmath<1.4.0,>=1.1.0 (from sympy->torch->mlc-llm-nightly-cu122)
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 49.4 MB/s eta 0:00:00
# Collecting shellingham>=1.3.0 (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->mlc-llm-nightly-cu122)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting rich>=10.11.0 (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->mlc-llm-nightly-cu122)
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 27.6 MB/s eta 0:00:00
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->mlc-llm-nightly-cu122)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 12.0 MB/s eta 0:00:00
# Collecting pygments<3.0.0,>=2.13.0 (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->mlc-llm-nightly-cu122)
#   Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 68.9 MB/s eta 0:00:00
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->mlc-llm-nightly-cu122)
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: wcwidth, mpmath, websockets, uvloop, urllib3, ujson, typing-extensions, tqdm, tornado, sympy, sniffio, shortuuid, shellingham, safetensors, regex, pyyaml, python-multipart, python-dotenv, pygments, psutil, prompt-toolkit, orjson, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, mdurl, MarkupSafe, idna, httptools, h11, fsspec, filelock, exceptiongroup, dnspython, distro, decorator, cloudpickle, click, charset-normalizer, certifi, attrs, annotated-types, uvicorn, triton, scipy, requests, pydantic-core, nvidia-cusparse-cu12, nvidia-cudnn-cu12, ml-dtypes, markdown-it-py, jinja2, httpcore, email_validator, anyio, watchfiles, tiktoken, starlette, rich, pydantic, nvidia-cusolver-cu12, mlc-ai-nightly-cu122, httpx, typer, torch, openai, fastapi-cli, fastapi, mlc-llm-nightly-cu122
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.13
#     Uninstalling wcwidth-0.2.13:
#       Successfully uninstalled wcwidth-0.2.13
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.4
#     Uninstalling tqdm-4.66.4:
#       Successfully uninstalled tqdm-4.66.4
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.3.3
#     Uninstalling tornado-6.3.3:
#       Successfully uninstalled tornado-6.3.3
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.3.1
#     Uninstalling sniffio-1.3.1:
#       Successfully uninstalled sniffio-1.3.1
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.4.3
#     Uninstalling safetensors-0.4.3:
#       Successfully uninstalled safetensors-0.4.3
#   Attempting uninstall: regex
#     Found existing installation: regex 2023.12.25
#     Uninstalling regex-2023.12.25:
#       Successfully uninstalled regex-2023.12.25
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.16.1
#     Uninstalling Pygments-2.16.1:
#       Successfully uninstalled Pygments-2.16.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.43
#     Uninstalling prompt-toolkit-3.0.43:
#       Successfully uninstalled prompt-toolkit-3.0.43
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.3
#     Uninstalling networkx-3.3:
#       Successfully uninstalled networkx-3.3
#   Attempting uninstall: mdurl
#     Found existing installation: mdurl 0.1.2
#     Uninstalling mdurl-0.1.2:
#       Successfully uninstalled mdurl-0.1.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.5
#     Uninstalling MarkupSafe-2.1.5:
#       Successfully uninstalled MarkupSafe-2.1.5
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.6.0
#     Uninstalling fsspec-2023.6.0:
#       Successfully uninstalled fsspec-2023.6.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.14.0
#     Uninstalling filelock-3.14.0:
#       Successfully uninstalled filelock-3.14.0
#   Attempting uninstall: exceptiongroup
#     Found existing installation: exceptiongroup 1.2.1
#     Uninstalling exceptiongroup-1.2.1:
#       Successfully uninstalled exceptiongroup-1.2.1
#   Attempting uninstall: distro
#     Found existing installation: distro 1.7.0
#     Uninstalling distro-1.7.0:
#       Successfully uninstalled distro-1.7.0
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 2.2.1
#     Uninstalling cloudpickle-2.2.1:
#       Successfully uninstalled cloudpickle-2.2.1
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.2
#     Uninstalling charset-normalizer-3.3.2:
#       Successfully uninstalled charset-normalizer-3.3.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.2.2
#     Uninstalling certifi-2024.2.2:
#       Successfully uninstalled certifi-2024.2.2
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.2.0
#     Uninstalling attrs-23.2.0:
#       Successfully uninstalled attrs-23.2.0
#   Attempting uninstall: annotated-types
#     Found existing installation: annotated-types 0.6.0
#     Uninstalling annotated-types-0.6.0:
#       Successfully uninstalled annotated-types-0.6.0
#   Attempting uninstall: triton
#     Found existing installation: triton 2.2.0
#     Uninstalling triton-2.2.0:
#       Successfully uninstalled triton-2.2.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.18.2
#     Uninstalling pydantic_core-2.18.2:
#       Successfully uninstalled pydantic_core-2.18.2
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: markdown-it-py
#     Found existing installation: markdown-it-py 3.0.0
#     Uninstalling markdown-it-py-3.0.0:
#       Successfully uninstalled markdown-it-py-3.0.0
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.4
#     Uninstalling Jinja2-3.1.4:
#       Successfully uninstalled Jinja2-3.1.4
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.7.1
#     Uninstalling anyio-3.7.1:
#       Successfully uninstalled anyio-3.7.1
#   Attempting uninstall: rich
#     Found existing installation: rich 13.7.1
#     Uninstalling rich-13.7.1:
#       Successfully uninstalled rich-13.7.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.7.1
#     Uninstalling pydantic-2.7.1:
#       Successfully uninstalled pydantic-2.7.1
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.4
#     Uninstalling typer-0.9.4:
#       Successfully uninstalled typer-0.9.4
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1+cu121
#     Uninstalling torch-2.2.1+cu121:
#       Successfully uninstalled torch-2.2.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# astropy 5.3.4 requires numpy<2,>=1.21, but you have numpy 2.0.0rc1 which is incompatible.
# cudf-cu12 24.4.1 requires numpy<2.0a0,>=1.23, but you have numpy 2.0.0rc1 which is incompatible.
# cupy-cuda12x 12.2.0 requires numpy<1.27,>=1.20, but you have numpy 2.0.0rc1 which is incompatible.
# gcsfs 2023.6.0 requires fsspec==2023.6.0, but you have fsspec 2024.3.1 which is incompatible.
# google-colab 1.0.0 requires tornado==6.3.3, but you have tornado 6.4 which is incompatible.
# ibis-framework 8.0.0 requires numpy<2,>=1, but you have numpy 2.0.0rc1 which is incompatible.
# jupyter-server 1.24.0 requires anyio<4,>=3.1.0, but you have anyio 4.3.0 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.1.1 which is incompatible.
# numba 0.58.1 requires numpy<1.27,>=1.22, but you have numpy 2.0.0rc1 which is incompatible.
# rmm-cu12 24.4.0 requires numpy<2.0a0,>=1.23, but you have numpy 2.0.0rc1 which is incompatible.
# spacy 3.7.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# tensorflow 2.15.0 requires ml-dtypes~=0.2.0, but you have ml-dtypes 0.4.0 which is incompatible.
# tensorflow 2.15.0 requires numpy<2.0.0,>=1.23.5, but you have numpy 2.0.0rc1 which is incompatible.
# torchaudio 2.2.1+cu121 requires torch==2.2.1, but you have torch 2.3.0 which is incompatible.
# torchtext 0.17.1 requires torch==2.2.1, but you have torch 2.3.0 which is incompatible.
# torchvision 0.17.1+cu121 requires torch==2.2.1, but you have torch 2.3.0 which is incompatible.
# weasel 0.3.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# Successfully installed MarkupSafe-2.1.5 annotated-types-0.6.0 anyio-4.3.0 attrs-23.2.0 certifi-2024.2.2 charset-normalizer-3.3.2 click-8.1.7 cloudpickle-3.0.0 decorator-5.1.1 distro-1.9.0 dnspython-2.6.1 email_validator-2.1.1 exceptiongroup-1.2.1 fastapi-0.111.0 fastapi-cli-0.0.3 filelock-3.14.0 fsspec-2024.3.1 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 idna-3.7 jinja2-3.1.4 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.4.0 mlc-ai-nightly-cu122-0.15.dev347 mlc-llm-nightly-cu122-0.1.dev1226 mpmath-1.3.0 networkx-3.3 numpy-2.0.0rc1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 openai-1.28.1 orjson-3.10.3 prompt-toolkit-3.0.43 psutil-5.9.8 pydantic-2.7.1 pydantic-core-2.18.2 pygments-2.18.0 python-dotenv-1.0.1 python-multipart-0.0.9 pyyaml-6.0.1 regex-2024.5.10 requests-2.31.0 rich-13.7.1 safetensors-0.4.3 scipy-1.13.0 shellingham-1.5.4 shortuuid-1.0.13 sniffio-1.3.1 starlette-0.37.2 sympy-1.12.1rc1 tiktoken-0.6.0 torch-2.3.0 tornado-6.4 tqdm-4.66.4 triton-2.3.0 typer-0.12.3 typing-extensions-4.11.0 ujson-5.9.0 urllib3-2.2.1 uvicorn-0.29.0 uvloop-0.19.0 watchfiles-0.21.0 wcwidth-0.2.13 websockets-12.0

# %% [markdown]
# ***Note: Restart runtime before running the cell below***
#
# We explicitly install NumPy 1.23.5 as that's the supported version.

# %%
# !pip install numpy==1.23.5
# Out:
# Collecting numpy==1.23.5
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 37.5 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.0rc1
#     Uninstalling numpy-2.0.0rc1:
#       Successfully uninstalled numpy-2.0.0rc1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.1.1 which is incompatible.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.23.5 which is incompatible.
# spacy 3.7.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# tensorflow 2.15.0 requires ml-dtypes~=0.2.0, but you have ml-dtypes 0.4.0 which is incompatible.
# torchtext 0.17.1 requires torch==2.2.1, but you have torch 2.3.0 which is incompatible.
# torchvision 0.17.1+cu121 requires torch==2.2.1, but you have torch 2.3.0 which is incompatible.
# Successfully installed numpy-1.23.5

# %% [markdown]
# ***Note: Restart the runtime again before running the cell below***

# %% [markdown]
# #### Step 2: Import libraries

# %%
import mlc_llm
import torch
from huggingface_hub import snapshot_download

# %% [markdown]
# #### Step 3: Login to Hugging Face account

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# #### Step 4: Download Llama-3-8B-Instruct model

# %%
# Download Llama-3-8B-Instruct model.
snapshot_download(repo_id="meta-llama/Meta-Llama-3-8B-Instruct", local_dir="/content/Llama-3-8B-Instruct/")
# Out:
# Fetching 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# '/content/Llama-3-8B-Instruct'

# %% [markdown]
# #### Step 5: Check GPU is enabled

# %%
# !nvidia-smi
# Out:
# Sun May 12 14:02:55 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# Check if CUDA is available.
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# #### Step 6: Configure model name and quantization type

# %%
MODEL_NAME = "Llama-3-8B-Instruct"
QUANTIZATION= "q4f16_1"

# %% [markdown]
# #### Step 7: Convert Llama-3-8B-Instruction model to MLC-compatible weights

# %%
# !python -m mlc_llm convert_weight /content/$MODEL_NAME/ --quantization $QUANTIZATION -o /content/$MODEL_NAME-$QUANTIZATION-android/
# Out:
# [2024-05-12 14:03:19] INFO auto_config.py:115: Found model configuration: /content/Llama-3-8B-Instruct/config.json
# [2024-05-12 14:03:22] INFO auto_device.py:79: Found device: cuda:0
# [2024-05-12 14:03:25] INFO auto_device.py:88: Not found device: rocm:0
# [2024-05-12 14:03:27] INFO auto_device.py:88: Not found device: metal:0
# [2024-05-12 14:03:31] INFO auto_device.py:88: Not found device: vulkan:0
# [2024-05-12 14:03:34] INFO auto_device.py:88: Not found device: opencl:0
# [2024-05-12 14:03:34] INFO auto_device.py:35: Using device: cuda:0
# [2024-05-12 14:03:34] INFO auto_weight.py:70: Finding weights in: /content/Llama-3-8B-Instruct
# [2024-05-12 14:03:34] INFO auto_weight.py:136: Not found Huggingface PyTorch
# [2024-05-12 14:03:34] INFO auto_weight.py:143: Found source weight format: huggingface-safetensor. Source configuration: /content/Llama-3-8B-Instruct/model.safetensors.index.json
# [2024-05-12 14:03:34] INFO auto_weight.py:106: Using source weight configuration: /content/Llama-3-8B-Instruct/model.safetensors.index.json. Use `--source` to override.
# [2024-05-12 14:03:34] INFO auto_weight.py:110: Using source weight format: huggingface-safetensor. Use `--source-format` to override.
# [2024-05-12 14:03:34] INFO auto_config.py:153: Found model type: llama. Use `--model-type` to override.
# Weight conversion with arguments:
#   --config          /content/Llama-3-8B-Instruct/config.json
#   --quantization    GroupQuantize(name='q4f16_1', kind='group-quant', group_size=32, quantize_dtype='int4', storage_dtype='uint32', model_dtype='float16', linear_weight_layout='NK', quantize_embedding=True, quantize_final_fc=True, num_elem_per_storage=8, num_storage_per_group=4, max_int_value=7)
#   --model-type      llama
#   --device          cuda:0
#   --source          /content/Llama-3-8B-Instruct/model.safetensors.index.json
#   --source-format   huggingface-safetensor
#   --output          /content/Llama-3-8B-Instruct-q4f16_1-android
# [2024-05-12 14:03:34] INFO llama_model.py:52: context_window_size not found in config.json. Falling back to max_position_embeddings (8192)
# [2024-05-12 14:03:34] INFO llama_model.py:72: prefill_chunk_size defaults to 2048
# Start storing to cache /content/Llama-3-8B-Instruct-q4f16_1-android
# [2024-05-12 14:03:40] INFO huggingface_loader.py:184: Loading HF parameters from: /content/Llama-3-8B-Instruct/model-00004-of-00004.safetensors
# [2024-05-12 14:03:53] INFO group_quantization.py:217: Compiling quantize function for key: ((128256, 4096), float16, cuda, axis=1, output_transpose=False)
# [2024-05-12 14:03:56] INFO huggingface_loader.py:166: [Quantized] Parameter: "lm_head.q_weight", shape: (128256, 512), dtype: uint32
# [2024-05-12 14:03:58] INFO huggingface_loader.py:166: [Quantized] Parameter: "lm_head.q_scale", shape: (128256, 128), dtype: float16
# [2024-05-12 14:03:58] INFO huggingface_loader.py:174: [Not quantized] Parameter: "model.layers.31.input_layernorm.weight", shape: (4096,), dtype: float16
# [2024-05-12 14:03:59] INFO group_quantization.py:217: Compiling quantize function for key: ((4096, 14336), float16, cuda, axis=1, output_transpose=False)
# [2024-05-12 14:03:59] INFO huggingface_loader.py:166: [Quantized] Parameter: "model.layers.31.mlp.down_proj.q_weight", shape: (4096, 1792), dtype: uint32
# [2024-05-12 14:03:59] INFO huggingface_loader.py:166: [Quantized] Parameter: "model.layers.31.mlp.down_proj.q_scale", shape: (4096, 448), dtype: float16
# [2024-05-12 14:04:00] INFO huggingface_loader.py:174: [Not quantized] Parameter: "model.layers.31.post_attention_layernorm.weight", shape: (4096,), dtype: float16
# [2024-05-12 14:04:00] INFO huggingface_loader.py:174: [Not quantized] Parameter: "model.norm.weight", shape: (4096,), dtype: float16
# [2024-05-12 14:04:00] INFO huggingface_loader.py:196: Unloading HF weight file: /content/Llama-3-8B-Instruct/model-00004-of-00004.safetensors
# [2024-05-12 14:04:00] INFO huggingface_loader.py:184: Loading HF parameters from: /content/Llama-3-8B-Instruct/model-00001-of-00004.safetensors
#   2% 3/195 [00:19<16:26,  5.14s/it]^C

# %% [markdown]
# #### Step 8: Generate token files

# %%
# !python -m mlc_llm gen_config /content/$MODEL_NAME/ --quantization $QUANTIZATION \
    --conv-template llama-3 --context-window-size 8192 --prefill-chunk-size 1024  \
    -o /content/$MODEL_NAME-$QUANTIZATION-android/
# Out:
# [2024-05-12 14:07:08] INFO auto_config.py:115: Found model configuration: /content/Llama-3-8B-Instruct/config.json
# [2024-05-12 14:07:08] INFO auto_config.py:153: Found model type: llama. Use `--model-type` to override.
# [2024-05-12 14:07:08] INFO llama_model.py:52: context_window_size not found in config.json. Falling back to max_position_embeddings (8192)
# [2024-05-12 14:07:08] INFO llama_model.py:72: prefill_chunk_size defaults to 2048
# [2024-05-12 14:07:08] INFO config.py:106: Overriding context_window_size from 8192 to 8192
# [2024-05-12 14:07:08] INFO config.py:106: Overriding prefill_chunk_size from 2048 to 1024
# [2024-05-12 14:07:08] INFO config.py:106: Overriding max_batch_size from 1 to 80
# [2024-05-12 14:07:08] INFO gen_config.py:255: [generation_config.json] Setting bos_token_id: 128000
# [2024-05-12 14:07:08] INFO gen_config.py:255: [generation_config.json] Setting eos_token_id: [128001, 128009]
# [2024-05-12 14:07:08] INFO gen_config.py:255: [generation_config.json] Setting temperature: 0.6
# [2024-05-12 14:07:08] INFO gen_config.py:255: [generation_config.json] Setting top_p: 0.9
# [2024-05-12 14:07:08] INFO gen_config.py:269: Not found tokenizer config: /content/Llama-3-8B-Instruct/tokenizer.model
# [2024-05-12 14:07:08] INFO gen_config.py:267: Found tokenizer config: /content/Llama-3-8B-Instruct/tokenizer.json. Copying to /content/Llama-3-8B-Instruct-q4f16_1-android/tokenizer.json
# [2024-05-12 14:07:08] INFO gen_config.py:269: Not found tokenizer config: /content/Llama-3-8B-Instruct/vocab.json
# [2024-05-12 14:07:08] INFO gen_config.py:269: Not found tokenizer config: /content/Llama-3-8B-Instruct/merges.txt
# [2024-05-12 14:07:08] INFO gen_config.py:269: Not found tokenizer config: /content/Llama-3-8B-Instruct/added_tokens.json
# [2024-05-12 14:07:08] INFO gen_config.py:267: Found tokenizer config: /content/Llama-3-8B-Instruct/tokenizer_config.json. Copying to /content/Llama-3-8B-Instruct-q4f16_1-android/tokenizer_config.json
# [2024-05-12 14:07:09] INFO gen_config.py:80: [System default] Setting pad_token_id: 0
# [2024-05-12 14:07:09] INFO gen_config.py:80: [System default] Setting presence_penalty: 0.0
# [2024-05-12 14:07:09] INFO gen_config.py:80: [System default] Setting frequency_penalty: 0.0
# [2024-05-12 14:07:09] INFO gen_config.py:80: [System default] Setting repetition_penalty: 1.0
# [2024-05-12 14:07:09] INFO gen_config.py:80: [System default] Setting mean_gen_len: 128
# [2024-05-12 14:07:09] INFO gen_config.py:80: [System default] Setting max_gen_len: 512
# [2024-05-12 14:07:09] INFO gen_config.py:80: [System default] Setting shift_fill_factor: 0.3
# [2024-05-12 14:07:09] INFO gen_config.py:335: Dumping configuration file to: /content/Llama-3-8B-Instruct-q4f16_1-android/mlc-chat-config.json

# %% [markdown]
# #### Step 9: Compile the model to Android format

# %%
# !python -m mlc_llm compile /content/$MODEL_NAME-$QUANTIZATION-android/mlc-chat-config.json \
    --device android -o /content/$MODEL_NAME-$QUANTIZATION-android/$MODEL_NAME-$QUANTIZATION-android.tar
# Out:
# [2024-05-12 14:14:06] INFO auto_config.py:69: Found model configuration: /content/Llama-3-8B-Instruct-q4f16_1-android/mlc-chat-config.json
# [2024-05-12 14:14:06] INFO auto_config.py:153: Found model type: llama. Use `--model-type` to override.
# [2024-05-12 14:14:06] WARNING auto_target.py:361: --system-lib-prefix is automatically picked from the filename, llama_q4f16_1_, this allows us to use the filename as the model_lib in android/iOS builds. Please avoid renaming the .tar file when uploading the prebuilt.
# Compiling with arguments:
#   --config          LlamaConfig(hidden_size=4096, intermediate_size=14336, num_attention_heads=32, num_hidden_layers=32, rms_norm_eps=1e-05, vocab_size=128256, position_embedding_base=500000.0, context_window_size=8192, prefill_chunk_size=1024, num_key_value_heads=8, head_dim=128, tensor_parallel_shards=1, max_batch_size=80, kwargs={})
#   --quantization    GroupQuantize(name='q4f16_1', kind='group-quant', group_size=32, quantize_dtype='int4', storage_dtype='uint32', model_dtype='float16', linear_weight_layout='NK', quantize_embedding=True, quantize_final_fc=True, num_elem_per_storage=8, num_storage_per_group=4, max_int_value=7)
#   --model-type      llama
#   --target          {"thread_warp_size": 1, "host": {"kind": "llvm", "tag": "", "keys": ["arm_cpu", "cpu"], "mtriple": "aarch64-linux-android"}, "texture_spatial_limit": 16384, "max_threads_per_block": 256, "max_function_args": 128, "max_num_threads": 256, "kind": "opencl", "max_shared_memory_per_block": 16384, "tag": "", "keys": ["opencl", "gpu"]}
#   --opt             flashinfer=0;cublas_gemm=0;faster_transformer=0;cudagraph=0;cutlass=0;ipc_allreduce_strategy=NONE
#   --system-lib-prefix "llama_q4f16_1_"
#   --output          /content/Llama-3-8B-Instruct-q4f16_1-android/Llama-3-8B-Instruct-q4f16_1-android.tar
#   --overrides       context_window_size=None;sliding_window_size=None;prefill_chunk_size=None;attention_sink_size=None;max_batch_size=None;tensor_parallel_shards=None
# [2024-05-12 14:14:06] INFO compile.py:138: Creating model from: LlamaConfig(hidden_size=4096, intermediate_size=14336, num_attention_heads=32, num_hidden_layers=32, rms_norm_eps=1e-05, vocab_size=128256, position_embedding_base=500000.0, context_window_size=8192, prefill_chunk_size=1024, num_key_value_heads=8, head_dim=128, tensor_parallel_shards=1, max_batch_size=80, kwargs={})
# [2024-05-12 14:14:06] INFO compile.py:157: Exporting the model to TVM Unity compiler
# [2024-05-12 14:14:11] INFO compile.py:163: Running optimizations using TVM Unity
# [2024-05-12 14:14:11] INFO compile.py:182: Registering metadata: {'model_type': 'llama', 'quantization': 'q4f16_1', 'context_window_size': 8192, 'sliding_window_size': -1, 'attention_sink_size': -1, 'prefill_chunk_size': 1024, 'tensor_parallel_shards': 1, 'kv_cache_bytes': 0}
# [2024-05-12 14:14:13] INFO pipeline.py:52: Running TVM Relax graph-level optimizations
# [2024-05-12 14:16:15] INFO pipeline.py:52: Lowering to TVM TIR kernels
# [2024-05-12 14:16:24] INFO pipeline.py:52: Running TVM TIR-level optimizations
# [2024-05-12 14:16:56] INFO pipeline.py:52: Running TVM Dlight low-level optimizations
# [2024-05-12 14:16:58] INFO pipeline.py:52: Lowering to VM bytecode
# [2024-05-12 14:17:04] INFO estimate_memory_usage.py:57: [Memory usage] Function `alloc_embedding_tensor`: 8.00 MB
# [2024-05-12 14:17:04] INFO estimate_memory_usage.py:57: [Memory usage] Function `batch_decode`: 11.56 MB
# [2024-05-12 14:17:04] INFO estimate_memory_usage.py:57: [Memory usage] Function `batch_decode_to_last_hidden_states`: 12.19 MB
# [2024-05-12 14:17:05] INFO estimate_memory_usage.py:57: [Memory usage] Function `batch_prefill`: 148.00 MB
# [2024-05-12 14:17:05] INFO estimate_memory_usage.py:57: [Memory usage] Function `batch_prefill_to_last_hidden_states`: 156.00 MB
# [2024-05-12 14:17:05] INFO estimate_memory_usage.py:57: [Memory usage] Function `batch_select_last_hidden_states`: 0.62 MB
# [2024-05-12 14:17:05] INFO estimate_memory_usage.py:57: [Memory usage] Function `batch_verify`: 148.00 MB
# [2024-05-12 14:17:05] INFO estimate_memory_usage.py:57: [Memory usage] Function `batch_verify_to_last_hidden_states`: 156.00 MB
# [2024-05-12 14:17:05] INFO estimate_memory_usage.py:57: [Memory usage] Function `create_tir_paged_kv_cache`: 0.00 MB
# [2024-05-12 14:17:05] INFO estimate_memory_usage.py:57: [Memory usage] Function `decode`: 0.14 MB
# [2024-05-12 14:17:05] INFO estimate_memory_usage.py:57: [Memory usage] Function `decode_to_last_hidden_states`: 0.15 MB
# [2024-05-12 14:17:05] INFO estimate_memory_usage.py:57: [Memory usage] Function `embed`: 8.00 MB
# [2024-05-12 14:17:05] INFO estimate_memory_usage.py:57: [Memory usage] Function `gather_hidden_states`: 0.00 MB
# [2024-05-12 14:17:05] INFO estimate_memory_usage.py:57: [Memory usage] Function `get_logits`: 0.00 MB
# [2024-05-12 14:17:05] INFO estimate_memory_usage.py:57: [Memory usage] Function `prefill`: 148.01 MB
# [2024-05-12 14:17:05] INFO estimate_memory_usage.py:57: [Memory usage] Function `prefill_to_last_hidden_states`: 156.00 MB
# [2024-05-12 14:17:05] INFO estimate_memory_usage.py:57: [Memory usage] Function `scatter_hidden_states`: 0.00 MB
# [2024-05-12 14:17:05] INFO estimate_memory_usage.py:57: [Memory usage] Function `softmax_with_temperature`: 0.00 MB
# [2024-05-12 14:17:08] INFO pipeline.py:52: Compiling external modules
# [2024-05-12 14:17:08] INFO pipeline.py:52: Compilation complete! Exporting to disk
# [2024-05-12 14:17:17] INFO model_metadata.py:96: Total memory usage: 4464.13 MB (Parameters: 4308.13 MB. KVCache: 0.00 MB. Temporary buffer: 156.00 MB)
# [2024-05-12 14:17:17] INFO model_metadata.py:105: To reduce memory usage, tweak `prefill_chunk_size`, `context_window_size` and `sliding_window_size`
# [2024-05-12 14:17:17] INFO compile.py:204: Generated: /content/Llama-3-8B-Instruct-q4f16_1-android/Llama-3-8B-Instruct-q4f16_1-android.tar

# %% [markdown]
# #### Step 10: Push the converted model weights to Hugging Face

# %%
from huggingface_hub import whoami
from pathlib import Path

# Output directory.
output_dir = "/content/" + MODEL_NAME + "-" + QUANTIZATION + "-android/"
repo_name = "Llama-3-8B-q4f16_1-android"
username = whoami(token=Path("/root/.cache/huggingface/"))["name"]
repo_id = f"{username}/{repo_name}"

# %%
from huggingface_hub import upload_folder, create_repo

repo_id = create_repo(repo_id, exist_ok=True).repo_id
print(output_dir)

upload_folder(
    repo_id=repo_id,
    folder_path=output_dir,
    commit_message="Quantized Llama-3-8B-Instruct model for Android.",
    ignore_patterns=["step_*", "epoch_*"],
)
# Out:
# /content/Llama-3-8B-Instruct-q4f16_1-android/
# Llama-3-8B-Instruct-q4f16_1-android.tar:   0%|          | 0.00/512k [00:00<?, ?B/s]
# Upload 109 LFS files:   0%|          | 0/109 [00:00<?, ?it/s]
# params_shard_10.bin:   0%|          | 0.00/33.0M [00:00<?, ?B/s]
# params_shard_0.bin:   0%|          | 0.00/263M [00:00<?, ?B/s]
# params_shard_100.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_1.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_101.bin:   0%|          | 0.00/25.2M [00:00<?, ?B/s]
# params_shard_102.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_103.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_104.bin:   0%|          | 0.00/33.0M [00:00<?, ?B/s]
# params_shard_105.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_106.bin:   0%|          | 0.00/32.5M [00:00<?, ?B/s]
# params_shard_107.bin:   0%|          | 0.00/9.44M [00:00<?, ?B/s]
# params_shard_11.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_12.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_13.bin:   0%|          | 0.00/22.0M [00:00<?, ?B/s]
# params_shard_14.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_15.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_16.bin:   0%|          | 0.00/27.3M [00:00<?, ?B/s]
# params_shard_17.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_18.bin:   0%|          | 0.00/30.9M [00:00<?, ?B/s]
# params_shard_19.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_2.bin:   0%|          | 0.00/32.8M [00:00<?, ?B/s]
# params_shard_20.bin:   0%|          | 0.00/25.2M [00:00<?, ?B/s]
# params_shard_21.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_22.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_23.bin:   0%|          | 0.00/33.0M [00:00<?, ?B/s]
# params_shard_24.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_25.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_26.bin:   0%|          | 0.00/22.0M [00:00<?, ?B/s]
# params_shard_27.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_28.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_29.bin:   0%|          | 0.00/27.3M [00:00<?, ?B/s]
# params_shard_3.bin:   0%|          | 0.00/263M [00:00<?, ?B/s]
# params_shard_30.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_31.bin:   0%|          | 0.00/30.9M [00:00<?, ?B/s]
# params_shard_32.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_33.bin:   0%|          | 0.00/25.2M [00:00<?, ?B/s]
# params_shard_34.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_35.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_36.bin:   0%|          | 0.00/33.0M [00:00<?, ?B/s]
# params_shard_37.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_38.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_39.bin:   0%|          | 0.00/22.0M [00:00<?, ?B/s]
# params_shard_4.bin:   0%|          | 0.00/32.8M [00:00<?, ?B/s]
# params_shard_40.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_41.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_42.bin:   0%|          | 0.00/27.3M [00:00<?, ?B/s]
# params_shard_43.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_44.bin:   0%|          | 0.00/30.9M [00:00<?, ?B/s]
# params_shard_45.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_46.bin:   0%|          | 0.00/25.2M [00:00<?, ?B/s]
# params_shard_47.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_48.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_49.bin:   0%|          | 0.00/33.0M [00:00<?, ?B/s]
# params_shard_5.bin:   0%|          | 0.00/33.1M [00:00<?, ?B/s]
# params_shard_50.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_51.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_52.bin:   0%|          | 0.00/22.0M [00:00<?, ?B/s]
# params_shard_53.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_54.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_55.bin:   0%|          | 0.00/27.3M [00:00<?, ?B/s]
# params_shard_56.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_57.bin:   0%|          | 0.00/30.9M [00:00<?, ?B/s]
# params_shard_58.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_59.bin:   0%|          | 0.00/25.2M [00:00<?, ?B/s]
# params_shard_6.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_60.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_61.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_62.bin:   0%|          | 0.00/33.0M [00:00<?, ?B/s]
# params_shard_63.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_64.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_65.bin:   0%|          | 0.00/22.0M [00:00<?, ?B/s]
# params_shard_66.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_67.bin:   0%|          | 0.00/30.9M [00:00<?, ?B/s]
# params_shard_68.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_69.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_7.bin:   0%|          | 0.00/25.2M [00:00<?, ?B/s]
# params_shard_70.bin:   0%|          | 0.00/27.3M [00:00<?, ?B/s]
# params_shard_71.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_72.bin:   0%|          | 0.00/30.9M [00:00<?, ?B/s]
# params_shard_73.bin:   0%|          | 0.00/33.0M [00:00<?, ?B/s]
# params_shard_74.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_75.bin:   0%|          | 0.00/25.2M [00:00<?, ?B/s]
# params_shard_76.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_77.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_78.bin:   0%|          | 0.00/33.0M [00:00<?, ?B/s]
# params_shard_79.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_8.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_80.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_81.bin:   0%|          | 0.00/22.0M [00:00<?, ?B/s]
# params_shard_82.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_83.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_84.bin:   0%|          | 0.00/27.3M [00:00<?, ?B/s]
# params_shard_85.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_86.bin:   0%|          | 0.00/30.9M [00:00<?, ?B/s]
# params_shard_87.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_88.bin:   0%|          | 0.00/25.2M [00:00<?, ?B/s]
# params_shard_89.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_9.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_90.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_91.bin:   0%|          | 0.00/33.0M [00:00<?, ?B/s]
# params_shard_92.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_93.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_94.bin:   0%|          | 0.00/22.0M [00:00<?, ?B/s]
# params_shard_95.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_96.bin:   0%|          | 0.00/58.7M [00:00<?, ?B/s]
# params_shard_97.bin:   0%|          | 0.00/27.3M [00:00<?, ?B/s]
# params_shard_98.bin:   0%|          | 0.00/29.4M [00:00<?, ?B/s]
# params_shard_99.bin:   0%|          | 0.00/30.9M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/NSTiwari/Llama-3-8B-q4f16_1-android/commit/3c4bfb024f6237cdea5d6bed51ebcd711456313b', commit_message='Quantized Llama-3-8B-Instruct model for Android.', commit_description='', oid='3c4bfb024f6237cdea5d6bed51ebcd711456313b', pr_url=None, pr_revision=None, pr_num=None)
